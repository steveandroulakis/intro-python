# %% [markdown]
# # Introduction to Python: Basics
# [Steve Androulakis](http://github.com/steveandroulakis/)
#
# version 0.1, Released 21/11/2014
#
#
# *___A big thanks to the following Notebook, of which I derived much of the basic material.___*:
#
# *A Crash Course in Python for Scientists* by [Rick Muller](http://www.cs.sandia.gov/~rmuller/), Sandia National Laboratories
#
# This work is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US).

# %% [markdown]
# ## What You Need to Install
#
# * [Python](http://www.python.org) version 2.7;
# * [Numpy](http://www.numpy.org), the core numerical extensions for linear algebra and multidimensional arrays;
# * [Scipy](http://www.scipy.org), additional libraries for scientific programming;
# * [Matplotlib](http://matplotlib.sf.net), excellent plotting and graphing libraries;
# * [IPython](http://ipython.org), with the additional libraries required for the notebook interface.
#
# The easiest way to get all of these installed and working on your system is [Anaconda](http://continuum.io/downloads).

# %% [markdown]
# ## Using Python as a Calculator

# %% [markdown]
# At its core, Python can be used as a calculator.

# %%
2+2
# Out:
# 4

# %%
(50-5*6)/4
# Out:
# 5

# %% [markdown]
# (If you're typing this into an IPython notebook, or otherwise using notebook file, you hit shift-Enter to evaluate a cell.)

# %% [markdown]
# There are some gotchas compared to using a normal calculator. We'll come back to this soon.

# %%
7/3
# Out:
# 2

# %% [markdown]
# ## Variables and types

# %% [markdown]
# A variable stores a value. This value can changed, and has a name..

# %%
a = 1
b = 2

a + b
# Out:
# 3

# %% [markdown]
# The result of calculations can also be stored in a variable.

# %%
width = 20
length = 30
area = length*width
area
# Out:
# 600

# %%
depth = 10
volume = area*depth
volume
# Out:
# 6000

# %% [markdown]
# Variables also have a type. For example, some processes may expect numbers.

# %%
import math
number_variable = 81
math.sqrt(number_variable)
# Out:
# 9.0

# %% [markdown]
# Some work well with text (strings).

# %%
text_variable = "Steve"
len(text_variable)
# Out:
# 5

# %% [markdown]
# There are several types, some of which we'll cover in this tutorial.

# %% [markdown]
# *Note: the last two examples covered a couple of new concepts: functions/methods and importing.*
#
# ___Import___ is how you take other people's code and have it usable from inside yours. This will be used extensively later.
#
# ___Functions/Methods___ are pieces of code elsewhere that you can use to get a result. Don't worry about the difference between functions and methods for now..

# %% [markdown]
# The division example earlier didn't work how you expected it to because dividing two whole numbers, or *integers* has an integer result.

# %%
7/3
# Out:
# 2

# %% [markdown]
# If one of the numbers in the operation is specified as a decimal number, or *float*, then the result will also be a float, and hence the answer will be much more accurate.

# %%
7/3.0
# Out:
# 2.3333333333333335

# %% [markdown]
# These also work. *float()* is a function built in to python.

# %%
# dropping the 0 is a shortcut
answer_1 = 7/3.

# float() is a function that forces 3 to be seen as a floating point number
answer_2 = 7/float(3)

print answer_1

print answer_2
# Out:
# 2.33333333333
# 2.33333333333

# %% [markdown]
# ## Strings
# Strings are lists of printable characters, and can be defined using either single quotes

# %%
'Hello, World!'
# Out:
# 'Hello, World!'

# %% [markdown]
# or double quotes

# %%
"Hello, World!"
# Out:
# 'Hello, World!'

# %% [markdown]
# Just like the other two data objects we're familiar with (ints and floats), you can assign a string to a variable

# %%
greeting = "Hello, World!"

# %% [markdown]
# The **print** statement is often used for printing character strings:

# %%
print greeting
# Out:
# Hello, World!

# %% [markdown]
# But it can also print data types other than strings:

# %%
print "The area is",area
# Out:
# The area is 600

# %% [markdown]
# In the above snippet, the number 600 (stored in the variable "area") is converted into a string before being printed out.

# %% [markdown]
# You can use the + operator to concatenate strings together:

# %%
statement = "Hello" + "," + "World!"
print statement
# Out:
# Hello,World!

# %% [markdown]
# Don't forget the space between the strings, if you want one there.

# %% [markdown]
# ## Lists
# Very often in a programming language, one wants to keep a group of similar items together. Python does this using a data type called **lists**.

# %%
days_of_the_week = ["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]

# %% [markdown]
# You can access members of the list using the **index** of that item:

# %%
days_of_the_week[2]
# Out:
# 'Tuesday'

# %% [markdown]
# Python, like many languages uses 0 as the first index in a list.

# %% [markdown]
# You can add additional items to the list using the .append() command:

# %%
people = ["Jess","John","Ricardo"]
people.append("Kelly")
print people
# Out:
# ['Jess', 'John', 'Ricardo', 'Kelly']

# %% [markdown]
# The built in function *help* allows you to find out about a function.

# %%
help(len)
# Out:
# Help on built-in function len in module __builtin__:
#
# len(...)
#     len(object) -> integer
#
#     Return the number of items of a sequence or mapping.

# %% [markdown]
# ## Iteration, Indentation, and Blocks
# One of the most useful things you can do with lists is to *iterate* through them, i.e. to go through each element one at a time. To do this in Python, we use the **for** statement:

# %%
days_of_the_week = ["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]

for day in days_of_the_week:
    print day
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday

# %% [markdown]
# This code snippet goes through each element of the list called **days_of_the_week** and assigns it to the variable **day**. It then executes everything in the indented block (in this case only one line of code, the print statement) using those variable assignments. When the program has gone through every element of the list, it exists the block.
#
# Python uses a colon (":"), followed by indentation level to define code blocks. Everything at a higher level of indentation is taken to be in the same block. In the above example the block was only a single line, but we could have had longer blocks as well:

# %%
for day in days_of_the_week:
    statement = "Today is " + day
    print statement
# Out:
# Today is Sunday
# Today is Monday
# Today is Tuesday
# Today is Wednesday
# Today is Thursday
# Today is Friday
# Today is Saturday

# %% [markdown]
# The **range()** command is particularly useful with the **for** statement to execute loops of a specified length:

# %%
for i in range(20):
    print "The square of ",i," is ",i*i
# Out:
# The square of  0  is  0
# The square of  1  is  1
# The square of  2  is  4
# The square of  3  is  9
# The square of  4  is  16
# The square of  5  is  25
# The square of  6  is  36
# The square of  7  is  49
# The square of  8  is  64
# The square of  9  is  81
# The square of  10  is  100
# The square of  11  is  121
# The square of  12  is  144
# The square of  13  is  169
# The square of  14  is  196
# The square of  15  is  225
# The square of  16  is  256
# The square of  17  is  289
# The square of  18  is  324
# The square of  19  is  361

# %% [markdown]
# ## Booleans and Truth Testing
# We have now learned a few data types. We have integers and floating point numbers, strings, and lists to contain them. We have also learned about lists, a container that can hold any data type. We have learned to print things out, and to iterate over items in lists. We will now learn about **boolean** variables that can be either True or False.
#
# We invariably need some concept of *conditions* in programming to control branching behavior, to allow a program to react differently to different situations. If it's Monday, I'll go to work, but if it's Sunday, I'll sleep in. To do this in Python, we use a combination of **boolean** variables, which evaluate to either True or False, and **if** statements, that control branching based on boolean values.

# %% [markdown]
# For example:

# %%
day = "Saturday"

if day == "Sunday":
    print "Sleep in"
else:
    print "Go to work"
# Out:
# Go to work

# %%
day == "Sunday"
# Out:
# True

# %% [markdown]
# If we evaluate it by itself, as we just did, we see that it returns a boolean value, False. The "==" operator performs *equality testing*. If the two items are equal, it returns True, otherwise it returns False. In this case, it is comparing two variables, the string "Sunday", and whatever is stored in the variable "day", which, in this case, is the other string "Saturday". Since the two strings are not equal to each other, the truth test has the false value.

# %% [markdown]
# The if statement that contains the truth test is followed by a code block (a colon followed by an indented block of code). If the boolean is true, it executes the code in that block. Since it is false in the above example, we don't see that code executed.
#
# The first block of code is followed by an **else** statement, which is executed if nothing else in the above if statement is true. Since the value was false, this code is executed, which is why we see "Go to work".
#
# You can compare any data types in Python:

# %%
1 == 2
# Out:
# False

# %%
50 == 2*25
# Out:
# True

# %%
3 < 3.14159
# Out:
# True

# %%
1 == 1.0
# Out:
# True

# %%
1 != 0
# Out:
# True

# %%
1 <= 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %% [markdown]
# We can do boolean tests on lists as well:

# %%
[1,2,3] == [1,2,4]
# Out:
# False

# %%
[1,2,3] < [1,2,4]
# Out:
# True

# %%
day = "Saturday"

if day == "Sunday":
    print "Sleep in"
elif day == "Saturday":
    print "Do chores"
else:
    print "Go to work"
# Out:
# Do chores

# %% [markdown]
# Of course we can combine if statements with for loops, to make a snippet that is almost interesting:

# %%
for day in days_of_the_week:
    statement = "Today is " + day
    print statement
    if day == "Sunday":
        print "   Sleep in"
    elif day == "Saturday":
        print "   Do chores"
    else:
        print "   Go to work"
# Out:
# Today is Sunday
#    Sleep in
# Today is Monday
#    Go to work
# Today is Tuesday
#    Go to work
# Today is Wednesday
#    Go to work
# Today is Thursday
#    Go to work
# Today is Friday
#    Go to work
# Today is Saturday
#    Do chores

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# **Dictionaries** are an object called "mappings" or "associative arrays" in other languages. Whereas a list associates an integer index with a set of objects:

# %%
mylist = [1,2,9,21]

# %% [markdown]
# The index in a dictionary is called the *key*, and the corresponding dictionary entry is the *value*. A dictionary can use (almost) anything as the key. Whereas lists are formed with square brackets [], dictionaries use curly brackets {}:

# %%
ages = {"Rick": 46, "Bob": 86, "Fred": 21}

print "Rick's age is ",ages["Rick"]
# Out:
# Rick's age is  46

# %% [markdown]
# More examples of retreiving by key.

# %%
print ages['Rick']
print ages['Fred']
# Out:
# 46
# 21

# %% [markdown]
# The **len()** command works on dictionaries:

# %%
len(ages)
# Out:
# steve
# steve
# steve

# %% [markdown]
# ## Functions: A Quick Rundown

# %% [markdown]
# It's important not to repeat yourself (known as 'DRY') when coding. Wrapping useful parts of code that you want to re-use in a *function* is a key concept.
#
# For example, if we wanted to repeat a word a specified number of times, we may just use loops, or 'the long way' (*remember: 'range' combined with 'for' allows us to repeat a statement a number of times):

# %%
for i in range(3):
    print 'hello'
    
for i in range(2):
    print 'bye'
# Out:
# hello
# hello
# hello
# bye
# bye

# %% [markdown]
# Yet even this amount of code has many similarities, and if we wanted to do this later on we would find ourselves repeating the same logic over again.
#
# Defining a function allows us to not repeat ourselves. In this example, the function name is *repeater* and it takes two variables known as arguments, *word* and *repeats*.

# %%
def repeater(word, repeats):
    for i in range(repeats):
        print word + ' '

# %% [markdown]
# Now this function has been defined, we can use it to get the same result as before.

# %%
repeater('hello', 3)
repeater('bye', 2)
# Out:
# hello
# hello
# hello
# bye
# bye

# %% [markdown]
# And again for a new case.

# %%
repeater('Aussie', 3)
repeater('Oi', 3)
# Out:
# Aussie
# Aussie
# Aussie
# Oi
# Oi
# Oi

# %% [markdown]
# ## Plotting with Matplotlib
# Python has a fantastic plotting library called [Matplotlib](http://matplotlib.sf.net). The IPython notebook interface we are using for these notes has that functionality built in.
#
# Tip: use __%matplotlib inline__ in iPython Notebook to have graphs load in the page.

# %%
# %matplotlib inline

# %% [markdown]
# Lets import the matplotlib package so we can use it. We will also import a powerful mathematics package, *numpy* to calculate figures to plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Now we use the Matplotlib function to plot a graph. The *as* keyword allows us to give these packages shorthand names for easier use.
#
# First, use numpy to get a range of points on the x-axis list of numbers to plot.
#
# *Give me 500 evenly spaced numbers between 0 and 2*pi.*

# %%
x = np.linspace(0, 2*np.pi, num=500)
x
# Out:
# array([ 0.        ,  0.01259155,  0.02518311,  0.03777466,  0.05036621,
#         0.06295777,  0.07554932,  0.08814088,  0.10073243,  0.11332398,
#         0.12591554,  0.13850709,  0.15109864,  0.1636902 ,  0.17628175,
#         0.18887331,  0.20146486,  0.21405641,  0.22664797,  0.23923952,
#         0.25183107,  0.26442263,  0.27701418,  0.28960574,  0.30219729,
#         0.31478884,  0.3273804 ,  0.33997195,  0.3525635 ,  0.36515506,
#         0.37774661,  0.39033817,  0.40292972,  0.41552127,  0.42811283,
#         0.44070438,  0.45329593,  0.46588749,  0.47847904,  0.4910706 ,
#         0.50366215,  0.5162537 ,  0.52884526,  0.54143681,  0.55402836,
#         0.56661992,  0.57921147,  0.59180302,  0.60439458,  0.61698613,
#         0.62957769,  0.64216924,  0.65476079,  0.66735235,  0.6799439 ,
#         0.69253545,  0.70512701,  0.71771856,  0.73031012,  0.74290167,
#         0.75549322,  0.76808478,  0.78067633,  0.79326788,  0.80585944,
# ...

# %% [markdown]
# We will then use this as part of a linear function.

# %%
plt.plot(x, np.sin(x**2))
plt.title('sin(x^2)');

# %% [markdown]
# And for another, silly example. 50 random numbers between 0 and 1.

# %%
from random import random
rands = []
for i in range(50):
    rands.append(random())
plt.plot(rands)
plt.title('Crazy Random')

# %% [markdown]
# ## Working With Files And Directories

# %% [markdown]
# Python scripts execute from a directory on your computer. iPython Notebook also executes from a particular place. At the beginning of execution this is called the 'current working directory' or *cwd*. Python includes the 'os' module. We can import it and then use the *getcwd()* command to find where this notebook is executing from.

# %%
import os
os.getcwd()
# Out:
# '/Users/steve/Documents/git/intro-python/intro-python'

# %% [markdown]
# We can supply this result to the *listdir()* function to see what files and directories sit with this iPython Notebook. This is returned as a Python list of names (strings).

# %%
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '01-python-basics.ipynb',
#  'melb.jpg',
#  'README.md']

# %% [markdown]
# Since these file names are in the current working dir (*cwd*), we can reference them by just using the file name. There's no need to cite the whole path. We can retreive the entire file system path, or 'absolute path' for a file with the *abspath()* command.

# %%
full_path = os.path.abspath('01-python-basics.ipynb')
full_path
# Out:
# '/Users/steve/Documents/git/intro-python/intro-python/01-python-basics.ipynb'

# %% [markdown]
# The inverse is also true: We can use the full path to a file to retreive just its filename with the *basename()* command.

# %%
filename = os.path.basename(full_path)
print filename
# Out:
# 01-python-basics.ipynb

# %% [markdown]
# ## Manipulating Images With Python

# %% [markdown]
# Writing Python code is often the process of gluing together other people's code to get a result that helps you. These tools, called modules are the real power of Python and other popular languages. Python can be used to do almost anything computational, from handling people requesting videos online (YouTube uses Python) to processing large amounts of data of all kinds.
#
# The following quick example utilises several available modules, such as matplotlib, scipy and numpy to perform basic actions on an image. Although this code draws on aspects covered in this tutorial, it's reasonably complex and only serves as a demonstration of what's possible with a handful of lines of code and the right tools.

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy import misc
from scipy import ndimage
import Image

melb_image = Image.open('melb.jpg')
melb_image_array = np.asarray(tt)

ypixels, xpixels, bands = ttt.shape

# get the size in inches
dpi = 72.
xinch = xpixels / dpi
yinch = ypixels / dpi

# plot and save in the same size as the original
fig = plt.figure(figsize=(xinch,yinch))

plt.imshow(melb_image_array, interpolation='none')

# %% [markdown]
# really cool. Now lets manipulate it

# %%
# for the manipulation in the second plot
from skimage import data
from skimage import filter
from skimage import exposure

plt.figure(figsize = (16.0, 8.0))

# Convert to black and white
melb_bw = melb_image.convert("L")
melb_bw_arr = np.asarray(melb_bw)

# Plot the grayscale image
plt.subplot(1,3,1)
plt.imshow(melb_bw_arr, interpolation = 'nearest', cmap = cm.Greys_r)
plt.clim([0,255])

# image thresholding using Otsu's method
# http://en.wikipedia.org/wiki/Otsu%27s_method
# requires black and white image
val = filter.threshold_otsu(melb_bw_arr)

# Plot the thresholded image
plt.subplot(1,3,2)
plt.imshow(melb_bw_arr < val, cmap='gray', interpolation='nearest')

# Rotate the original image 45 degrees
melbrotate = ndimage.rotate(melb, 45)

# Plot the rotated image
plt.subplot(1,3,3)
plt.imshow(melbrotate, interpolation = 'nearest')

plt.show()
